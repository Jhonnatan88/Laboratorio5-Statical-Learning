# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("Live.csv")
df1
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
df = df1.iloc[:, 1:12]
df
# Out:
#      status_type status_published  num_reactions  num_comments  num_shares  \
# 0          video   4/22/2018 6:00            529           512         262
# 1          photo  4/21/2018 22:45            150             0           0
# 2          video   4/21/2018 6:17            227           236          57
# 3          photo   4/21/2018 2:29            111             0           0
# 4          photo   4/18/2018 3:22            213             0           0
# ...          ...              ...            ...           ...         ...
# 7045       photo   9/24/2016 2:58             89             0           0
# 7046       photo  9/23/2016 11:19             16             0           0
# 7047       photo  9/21/2016 23:03              2             0           0
# 7048       photo   9/20/2016 0:43            351            12          22
# 7049       photo  9/10/2016 10:30             17             0           0
#
# ...

# %% [markdown]
# # Realice un análisis estadístico de cada variable dentro del dataset Live.csv las cuales  apliquen (todas excepto status_id, status_published), esto es:

# %% [markdown]
# # Gráfica del histograma y distribución de las variables numéricas continuas, promedio, mediana, varianza, desviación estándar, rango y describe

# %%
df.drop(['status_type','status_published','num_reactions'], 1).hist()
plt.show()
# Out:
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\2868729147.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['status_type','status_published','num_reactions'], 1).hist()

# %%
stats = df.describe()
print(stats)
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# # Distribución de frecuencias para las variables que se consideren discretas o categóricas.

# %%
print(df.groupby(['status_type']).count())
# Out:
#              status_published  num_reactions  num_comments  num_shares  \
# status_type
# link                       63             63            63          63
# photo                    4288           4288          4288        4288
# status                    365            365           365         365
# video                    2334           2334          2334        2334
#
#              num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# status_type
# link                63         63        63         63        63          63
# photo             4288       4288      4288       4288      4288        4288
# status             365        365       365        365       365         365
# video             2334       2334      2334       2334      2334        2334

# %% [markdown]
# # Muestre una gráfica de serie temporal (debe ordenar las fechas) para cada tipo de entidad:

# %%
df_series = df.sort_values(by=['status_published'])
df_series
# Out:
#      status_type status_published  num_reactions  num_comments  num_shares  \
# 3264       video    1/1/2018 1:39            296           869          58
# 3263       photo   1/1/2018 23:41             89             5          46
# 3954       photo    1/1/2018 8:57            342            34           1
# 2030       photo   1/10/2013 1:07              6             0           0
# 2028       photo  1/10/2013 20:49             58            19           0
# ...          ...              ...            ...           ...         ...
# 611        photo   9/9/2016 19:03             60             3           0
# 6799       video   9/9/2017 10:05            553         10926         429
# 3614       video   9/9/2017 22:43            284           562          93
# 6801       photo    9/9/2017 2:55            331           196           2
# 6800       video    9/9/2017 7:13            459          4391         201
#
# ...

# %%
x = df_series.status_published
y = df_series.num_reactions

#valores_iniciales2.shape
plt.plot( x,y , label='num_reactions')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_comments

#valores_iniciales2.shape
plt.plot( x,y , label='num_comments')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_shares

#valores_iniciales2.shape
plt.plot( x,y , label='num_shares')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_likes

#valores_iniciales2.shape
plt.plot( x,y , label='num_likes')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_loves

#valores_iniciales2.shape
plt.plot( x,y , label='num_loves')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_wows

#valores_iniciales2.shape
plt.plot( x,y , label='num_wows')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_hahas

#valores_iniciales2.shape
plt.plot( x,y , label='num_hahas')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_sads

#valores_iniciales2.shape
plt.plot( x,y , label='num_sads')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %%
x = df_series.status_published
y = df_series.num_angrys

#valores_iniciales2.shape
plt.plot( x,y , label='num_angrys')
#plt.plot(test_predict, label='forecast')
plt.legend()
plt.show()

# %% [markdown]
# # Separe el dataset en X e y donde y será la columna status_type
#
# Aplique el procedimiento de ingeniería de características para preparar el dataset
# para aplicar clustering sobre el, esto es:
# a. Convertir las variables categóricas a numéricas (incluyendo la y).
# b. Aplicar Feature Scaling (recomendamos MinMaxScaler).

# %%
df_series2 = df_series.iloc[:, df_series.columns != 'status_published']

# %%
df_series2.columns
# Out:
# Index(['status_type', 'num_reactions', 'num_comments', 'num_shares',
#        'num_likes', 'num_loves', 'num_wows', 'num_hahas', 'num_sads',
#        'num_angrys'],
#       dtype='object')

# %%
df_series2['status_type'] = df_series2['status_type'].replace(['video'],'1')
df_series2['status_type'] = df_series2['status_type'].replace(['photo'],'2')
df_series2['status_type'] = df_series2['status_type'].replace(['status'],'3')
df_series2['status_type'] = df_series2['status_type'].replace(['link'],'4')
# Out:
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\3618576079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_series2['status_type'] = df_series2['status_type'].replace(['video'],'1')
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\3618576079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_series2['status_type'] = df_series2['status_type'].replace(['photo'],'2')
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\3618576079.py:3: SettingWithCopyWarning:
# ...

# %%
y = df_series2.loc[:,'status_type']
x = df_series2.iloc[:, df_series2.columns != 'status_type']
y.shape, x.shape
# Out:
# ((7050,), (7050, 9))

# %%
y.unique()
# Out:
# array(['1', '2', '3', '4'], dtype=object)

# %% [markdown]
# # K-Means: Utilice el enfoque con las variables que quedaron como X para encontrar el numero de clusters más adecuado para agrupar los datos, recuerde que puede utilizar el metodo del codo para determinar cual es la cantidad de clusters adecuada, sin embargo en esta ocación debemos considerar cual es la cantidad de etiquetas colocadas correctamente a cada fila X y determinar el accuracy de la asignación.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# Normalizando la data
std_scaler = MinMaxScaler(feature_range = (0,1))

# %%
x = std_scaler.fit_transform(x)
x
# Out:
# array([[0.06284501, 0.04140067, 0.01693925, ..., 0.01273885, 0.01960784,
#         0.        ],
#        [0.01889597, 0.00023821, 0.01343458, ..., 0.        , 0.        ,
#         0.        ],
#        [0.07261146, 0.00161982, 0.00029206, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.06029724, 0.02677465, 0.02716121, ..., 0.01273885, 0.        ,
#         0.        ],
#        [0.07027601, 0.00933778, 0.00058411, ..., 0.00636943, 0.        ,
#         0.        ],
#        [0.09745223, 0.20919485, 0.05870327, ..., 0.08280255, 0.07843137,
#         0.03225806]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size =0.2 ,random_state = 2022
                                                    , shuffle = True)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 25)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.71      0.74       467
#            2       0.79      0.90      0.84       863
#            3       0.25      0.03      0.05        66
#            4       0.00      0.00      0.00        14
#
#     accuracy                           0.79      1410
#    macro avg       0.46      0.41      0.41      1410
# weighted avg       0.76      0.79      0.77      1410
#
# [[333 132   2   0]
#  [ 85 775   3   0]
#  [  8  56   2   0]
#  [  1  12   1   0]]
# D:\ProgramData\Anaconda3\envs\python\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn import metrics
print("Entrenar el set de Certeza: ", metrics.accuracy_score(y_train, classifier.predict(x_train)))
print("Probar el set de Certeza: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Entrenar el set de Certeza:  0.8024822695035461
# Probar el set de Certeza:  0.7872340425531915

# %%
cm =  confusion_matrix(y_test, y_pred )

# %%
import seaborn as sns
sns.heatmap(cm,cbar=False,cmap="Blues", annot = True, fmt="d")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
print("Error absoluto medio : %.2f"% metrics.mean_absolute_error(y_test,y_pred))
print("Error cuadrado medio : %.2f"% metrics.mean_squared_error(y_test,y_pred))
print("Error R2 : %.2f"% np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
# Out:
# Error absoluto medio : 0.23
# Error cuadrado medio : 0.27
# Error R2 : 0.48

# %% [markdown]
# # Aplique el método de PCA para realizar la clusterisación con el mismo criterio que se menciona en el inciso anterior.

# %%
(df['status_type']).unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
video = df[df['status_type'] == 'video']
photo = df[df['status_type'] == 'photo']
link = df[df['status_type'] == 'link']
status = df[df['status_type'] == 'status']
video.shape, photo.shape, link.shape, status.shape
# Out:
# ((2334, 11), (4288, 11), (63, 11), (365, 11))

# %%
video = video.sample(2*len(status), random_state=2022)
photo = photo.sample(2*len(status), random_state=2022)
video.shape, photo.shape, link.shape, status.shape
# Out:
# ((730, 11), (730, 11), (63, 11), (365, 11))

# %%
new_df = video.append([photo], ignore_index=True)
new_df = new_df.append([link], ignore_index=True)
new_df = new_df.append([status], ignore_index=True)
new_df.shape
# Out:
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\452644193.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = video.append([photo], ignore_index=True)
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\452644193.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append([link], ignore_index=True)
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\452644193.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append([status], ignore_index=True)
# (1888, 11)

# %%
new_df['status_type'] = new_df['status_type'].replace(['video'],'1')
new_df['status_type'] = new_df['status_type'].replace(['photo'],'2')
new_df['status_type'] = new_df['status_type'].replace(['status'],'3')
new_df['status_type'] = new_df['status_type'].replace(['link'],'4')

# %%
y = new_df.loc[:,'status_type']
x = new_df.iloc[:, new_df.columns != 'status_type']
x = new_df.iloc[:, new_df.columns != 'status_published']
y.shape, x.shape
# Out:
# ((1888,), (1888, 10))

# %%
x.dtypes
# Out:
# status_type      object
# num_reactions     int64
# num_comments      int64
# num_shares        int64
# num_likes         int64
# num_loves         int64
# num_wows          int64
# num_hahas         int64
# num_sads          int64
# num_angrys        int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, 
                                                    random_state=2022, shuffle=True)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.33798157, 0.22218042])

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.5601619933160058

# %%
np.round(pca.components_, 2)
# Out:
# array([[-0.18,  0.33,  0.29,  0.4 ,  0.29,  0.44,  0.34,  0.34,  0.1 ,
#          0.3 ],
#        [ 0.33,  0.58, -0.19, -0.22,  0.62, -0.2 ,  0.04, -0.15, -0.07,
#         -0.15]])

# %% [markdown]
# # Regresion Logsitica - PCA

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

rlog_clf_pca = LogisticRegression(random_state=0)
rlog_clf_pca.fit(x_train_pca, y_train)
preds_rlog_pca = rlog_clf_pca.predict(x_test_pca)
accuracy_score(y_test, preds_rlog_pca)
# Out:
# 0.9102564102564102

# %% [markdown]
# # SVM - PCA

# %%
from sklearn.svm import SVC 

svm_clf_pca = SVC()
svm_clf_pca.fit(x_train_pca, y_train)
preds_svm_pca = svm_clf_pca.predict(x_test_pca)
accuracy_score(y_test, preds_svm_pca)
# Out:
# 0.9230769230769231

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA
pcas = np.arange(2, 11)
accs = []

for pca in pcas:
    #Calculo PCA
    pca = PCA(n_components=pca)
    x_train_pca = pca.fit_transform(x_train)
    x_test_pca = pca.transform(x_test)
    
    #entrenamiento del modelo
    lgr_clf_pca = SVC()
    lgr_clf_pca.fit(x_train_pca, y_train)
    preds_lgr_pca = lgr_clf_pca.predict(x_test_pca)
    acc = accuracy_score(y_test, preds_lgr_pca)
    accs.append(acc)

plt.plot(pcas, accs, "-o", color="red")
plt.title("PCA con SVM")
plt.xlabel("Componentes Principales")
plt.ylabel("ACC")
plt.show()

# %%
pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(x_train)
X_test_pca = pca.transform(x_test)
rlog_clf_pca = SVC(random_state=0)
rlog_clf_pca.fit(x_train_pca, y_train)
preds_rlog_pca = rlog_clf_pca.predict(x_test_pca)
accuracy_score(y_test, preds_rlog_pca)
# Out:
# 0.9919871794871795

# %%
pca.explained_variance_ratio_
# Out:
# array([0.33798157, 0.22218042, 0.11479199, 0.09469844, 0.08093974])

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.8505921562208706

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %% [markdown]
# # T-SNE

# %%
from sklearn.manifold import TSNE
from keras.datasets import mnist

tsne = TSNE(n_components=2, verbose=1, random_state=123)
z = tsne.fit_transform(x)
# Out:
# D:\ProgramData\Anaconda3\envs\python\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\ProgramData\Anaconda3\envs\python\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1888 samples in 0.003s...
# [t-SNE] Computed neighbors for 1888 samples in 0.048s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1888
# [t-SNE] Computed conditional probabilities for sample 1888 / 1888
# [t-SNE] Mean sigma: 0.006522
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.368317
# [t-SNE] KL divergence after 1000 iterations: 0.369807

# %%
z.shape
# Out:
# (1888, 2)

# %%
df_subset = pd.DataFrame()

# %%
df_subset['tsne-2d-one'] = z[:,0]
df_subset['tsne-2d-two'] = z[:,1]

# %%
df_subset
# Out:
#       tsne-2d-one  tsne-2d-two
# 0        4.724689   -38.802319
# 1       52.491749    -0.966395
# 2       28.777987   -21.802588
# 3       -2.709298   -43.312386
# 4        1.604734   -31.268089
# ...           ...          ...
# 1883   -11.148736    -3.873461
# 1884    17.883770     9.774683
# 1885    19.131905     8.696557
# 1886     6.054054     2.205184
# 1887    18.794262     9.572252
#
# [1888 rows x 2 columns]

# %%
import seaborn as sns

plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    #hue="y",
    palette=sns.color_palette("hls", 10),
    data=df_subset,
    legend="full",
    alpha=0.3
)
# Out:
# C:\Users\Jhonnatan\AppData\Local\Temp\ipykernel_21800\1487319397.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# <AxesSubplot:xlabel='tsne-2d-one', ylabel='tsne-2d-two'>

# %% [markdown]
# # Finalmente compare cual es el método que obtiene mejor accuracy en la asignación de clusters para los datos.

# %% [markdown]
# ### El mejor resultado se obtuvo con PCA ya que sua accuracy fue mas alto.
